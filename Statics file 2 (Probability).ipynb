# %% [markdown]
# # Learning Objectives :-
# - Introdution
# - Key terms in probability
# - Types of probability
# - Addition rule of probability
# - Multiplication rule of probability
# - Baye's theorem

# %% [markdown]
# # Key terms in probability
# - Experiment
# - Outcome
# - Sample space
# - Event

# %% [markdown]
# # Probability
# - The probability of an event happening is defind as the ratio of the number of favouarable outcomes to the total number of possible outcomes.
#   -  P(A) = Number of times A occurs / Total number of possible out comes

# %% [markdown]
# # Types of probability
# <font size =5>1. Joint probability (A and B) (A ∩ B)
#  - That of event A and event B occurring to gether.
#     -  **Example** :- The probability of a card draw at random be a Jack and a Red.
#         - In this case
#         - Total Number of favorable outcomes = 2
#         - Total number of possible outcomes = 52

# %%
P = 2/52
print(P)
# Out:
# 0.038461538461538464

# %% [markdown]
# <font size =5>2. Conditional probability (A|B)
# - Conditional probability is a measure of the probability of an event occurring given that another event is already known to have occurred.
# - Conditional probability of an event A occurring is the likehood of event A happening given event B has already occurred.
#   - **Example** : - Given that you have drawn a red card. What is the probability that the red card is a Jack?
#     - Favorable outcomes is a jack of red = 2
#     - Total number of outcomes = total number of red cards = 26 , since we know that we have drawn a red card.
#     - P(Jack | Red) = 2/26 = 0.07

# %% [markdown]
# # Formula for conditional probability
#  - P(A|B) = P(A and B)/P(B)
# - For our cards problem
#   - P(Jack|Red) = P(jack and red) / P(red)

# %%
Probability = 2/52
print(Probability)
# Out:
# 0.038461538461538464

# %%
con_Jack_red = 26/52
print(con_Jack_red)
# Out:
# 0.5

# %%
Probability/con_Jack_red
# Out:
# 0.07692307692307693

# %% [markdown]
# <font size = 5> Example : - Medical Research on a new treatment <br>
# - You are a data scientist working on analyzing the effectivences of a new treatment.
# - whether or not participants have received the new treatment.
# - Whether or not participante showed improve in their condition after a certin period.
#     - Event A : A participante show imporvement
#     - Event B : A participante received the new treatment.
#       - From the clinial trial you have the following data.
#         - 200 participants in total
#         - 120 participants recevied the new treatment
#         - 80  participants showed imporvement
#         - 70  of the participants who showed imporvement had recevied the new treatment.
#     - Objective :- Calculate the conditional probability that a participants show improvement given that they received the new treatment.

# %%
Show_impro = 70/200
print(Show_impro)
Recevied_impro = 120/200
print(Recevied_impro)
Objective = Show_impro/Recevied_impro
print(Objective)
# Out:
# 0.35
# 0.6
# 0.5833333333333334

# %% [markdown]
# <font size =4 > Draw the intersection part in charts
# - Total = 200 Participants
# - A = 120 , Intersection(∩) = 70 , B = 10
# ![intersection-57c632dd5f9b5855e5848ee8.jpg](attachment:intersection-57c632dd5f9b5855e5848ee8.jpg)

# %% [markdown]
# # Type of events :-
#  - (Based on wether they can occurr simultaneously or not)

# %% [markdown]
# # Mutually Exclusive events : -
# - Events that connot simultaneously.
#   - Example :- Suppose you are drawing a card from a deck of cards you connot draw a heart and a spade at the same time thus the events of drawing a heart and a spade are mutually exclusive events.
#   - In a given population consider two events " being single". "These events are mutually exclusive because an individual cannot be both married and single at the same time.

# %% [markdown]
# # Mutually Inclusive events :-
# - That can occur simultaneoulsy.
#    - Example :- Suppose you are drawing a card from deck of cards. you can draw a king and heart at the same time.

# %% [markdown]
# # Addition rule of probability :
# - For mutually exclusive events :
#     - P(A or B) = P(A) + P(B)
#     - P(A ∩ B) = P(A) + P(B)
# - For mutually inclusive events :
#     - P(A or B) = (A ∩ B) = P(A) + P(B) - P(A and B)

# %% [markdown]
# # Types of events based on their dependence :
# - **Dependents Events**
#     - Two events A and B are dependents if the occurrence or non-occurrence of one events affects the probability of the other events(Same universe).
#       - Example :- The probability that a user purchase a product (Event A) may denpend on wether the user has recently viwed a related product (Event B).
#       - Drawing two cards from a deck of deck of cards one after the other.

# %% [markdown]
# - **Indepent Events**
#   - Two events A and B are indepentent if the occurence(or non-occurence) of one events does not affect the probability of the other events.(Diffrent Universe)
#      - Example :- Tossing a fair coin twice the outcome of the first toss not affect the outcomes of the second toss.
#       - A data scientist is analyzing the performance of two different machine learing models (model A and model B) on the same dataset.

# %% [markdown]
# # Multiple Rule of Probability
# - The multiplication rule is a way to find the probability of two events happening at the same time.
#    - For Indepent events
#      - P(A and B) = P(A) * P(B)
#    - For denpendent events
#      - P(A and B) = P(A) * P(B|A)

# %% [markdown]
# # How do we find that two events are dependent or not ?
#  - There are two formula to check for independance a many evets .
#     - formula 1 : P(A ∩ B) = P(A) * P(B)
#         - If the product of the individual probabilities equals the joint probability then the two evets are indenpent.
#     - formula 2 : P(A|B) = P(A)
#         - If the conditional probability is equal to the probability of a happening on its own, they are indenpent.

# %% [markdown]
# # How do we find that two events are dependent or not ?
#  - We cannot solely depend on the two probability formulas specially when dealing with real-world data.
# - Formula assume perfect information :
#     - The formula  P(A B) = P(A) * P(B) and  P(A|B) = P(A) assume we have perfect knowledge of the probabilities of all events however, in real-world scenoriors. we often work with samples of data that have inherent variability.
#     - Statistical tests account for sampling variablity statistical tests like the Chi-square take into account this sampling variablity and assess whether any observed differences in probabilies are likely due to chance or represent a true realationship between the variables.

# %% [markdown]
# # How do we find that two events are dependent or not ?
# - formula dno't account for uncetainty the-formula dnot account for the are inherent in real-world data.
# - Statistical tests incorporate uncerteinty :-
#     - statistical tests incorporate uncerteinty through measure like confidence intervals which provide a range of possible values for the true population proportions or probability

# %% [markdown]
# # Baye's Theorem :-
# - Before understanding the bayes theorem let us take a look at these concepts -
#   - **Posterior Probability** :- The updated probability of events A after considering new evidence B. Its writter as P(A|b).
#   - **Prior Probability** :- Your initial belief about the probability of an events A before considering any new evidence. Its written as P(A).
#   - **Likelihood** :- The probability of observing the evidence B event A were true. Its written as P(B|A)
#   - The bayes theorem states that
#      - P(A|B) = P(B|A) P(A)/P(B)
#   - Now the question arises why to use this formula to calculate the conditional probability (Posterior probability) in stead of the traditional formula for conditional probability?
#   - P(A|B) is the posterior probability of event A given the occurrence  of event B.
#   - P(B|A) is the likelyhood or conditional porbability of event B given that event A has occurred.
#   - P(A) is the prior probability of events A, Which is the probability of A before considering evidence B.
#   - P(B) is the probability of event B, the marginal likehood of observing B.

# %% [markdown]
# # Example :-
#  - Detecting covid diseaes apporch :
# - Prior probability of the disease (P(A)).
# - this reflets the estimated gobal precedence of the covid disase. while  the exact number may be unknowns, medical literature, historical outbreak data. and smilier case reports can offer valuable insights.

# %%
P_A = 10000/1000000
print(P_A)
# (10000 case in 10 lakh population) = 0.01
# Out:
# 0.01

# %% [markdown]
# - Likelyhood of symptoms given the disease P(B|A) :
#     - The represents the probability of observing the specific symptoms (fever,rash,etc). If the patient actually has the covid disease the doctor may consult research on the known clinical presentation of the disease and adjust based on the patients individual symptoms.
#     - P(B|A)= 0.8(80%)

# %% [markdown]
# - Prior probability of symptoms (P(B)):
#     - This accounts for the base line probability of thess symptoms occurring inthe general population regradless of the covid disease medical records and epidemidegical data can provide estimate for this value.
#     - P(B)=0.02(2%)

# %% [markdown]
# P(A|B) = P(B|A) * P(A) / P(B)

# %%
P_A = 0.8*0.01/0.02
P_A
# Out:
# 0.4

# %% [markdown]
# # Example : -
# - **Interpretion** :- Even though the symptoms are relatively here in the general population (2%) bayes singnificantly increases the probability of the patient haveing the exotic disease (40%). This information, while not conclusive,guides the doctor in recommending for ther investigations and specialist consultations.

# %% [markdown]
# # Prbability Distribution
# - A probability distribution is a mathematical function that gives the probabilty of occurrence of diffrent possbile outcome for an experiment.
# - There are two different types of probability distribution for the two different types of random variables.
# - **Discrete probability distribution** - A discrete distribution describes the probability of a occurrencce of each value of discrete random variable.
# - **Continuons probability distribution** - A continuons distribution describes the probabilities of continuons random variable possible values.

# %% [markdown]
# # Theratical Distribution :-
# - probability distribution of possible number of tail into toss.

# %% [raw]
# First Toss | Seceond Toss |Number of  tails two toss  |Probability
#   H 1/2    |     H 1/2    |      0                    |   0.25
#   H 1/2    |     T 1/2    |      1                    |   0.25
#   T 1/2    |     T 1/2    |      2                    |   0.25
#   T 1/2    |     H 1/2    |      1                    |   0.25

# %% [raw]
# Tails        |          Tosses        |      probabaility
#   0          |           (H-H)        |           0.25
#   1          |           (H-T)(T-H)   |         (0.25+0.25) = 0.50
#   2          |           (T-T)        |            0.25

# %% [raw]
#         |
#  0.50   |          |
#         |          |
#  0.25   |    |     |      |
#         |    |     |      |
#         |____|_____|______|
#              0     1      2

# %% [markdown]
# # Random Variable :-
# - A random variable is a variable whose value depends on the outcomes of a ramdom event.
# - A random variable may be denoted by symblos such as X or Y.
# - Imagine filipping a coin. The outcome of the filp is random either heads or tails we can define a random variable X that takes the values 1 if the outcome is heads and 0 if its tails, so the value of X depends on the ramdom event of flipping the coin.
# - Every feature (columns) in a data set is a random variable and every value.
# - A random variable X  is a numerical measure of the outcomes of an expreiment

# %% [markdown]
# # Probability Distribution :-
# - Probability distribution express distribution of probability over different values of concerned random variable.

# %% [markdown]
# # Different between frequency distribution and probability distribution?
#  - Frequency distribution is a listing of the obsevred frequencies of all the outcomes of an experiment that actually occurred when the experiment was done where as a probability distribution is a listing of the probabilities of all the pass possible outcomes that could result if the experiment were done.

# %% [markdown]
# # Some common probability distribution :-
# - The following are some common discrete probability distribution .
#   - Binomial Distribution
#   - Bernoulli Distribution
#   - Poisson Distribution
# - The following are some common continuons probability distribution .
#   - Normal distribution
#   - Standard normal distribution
#   - Chi-Squared distribution
#   - Student T's distribution
#   - Log normal distribution

# %% [markdown]
# # Why random variable :-
# - A Probability distribution is made of a random variable.
# - **Quantifying outcome** :- Probability distribution deal with the likehood of various outcomes them selves might be qualitative (e.g. Heads or tails on a coin) random variable assign a numerical value to each outcome making them easier to work with and compare.
# - **Modeling real-world phonomena** :- many real-world phonemena like waiting times error measurments or financial return can be modeled using probability distribution random variable the serve as a bridge between the mathematical model and the actual data allowing us to analyze and predict the behavior of the system.

# %% [markdown]
# - Discrete random variable .
# - Discrete random variable take on a countable number of discrete values .(i.e whole no.)
# - Example :
#     - Customer churn prediciton -
#     Churn (leave) and not churn(stoy)
#     Here the random variable X has the possible values 0 (Customer will churn) and 1 (Customer will not churn)
#
# - Continuous Random Variable :
# - Continuous random variable can represent any value with in a specified range.
# - Example :
#     - Advertising sales of a company -
#     The ramdom variable of can take the value Rs. - 1000.23,3000,1200.65 etc.

# %% [markdown]
# # Expected value (mean) of a Random variable :
# - The expected value of a random variable represents the average outcome of a random event, taking into account the probabilties of each possible outcome .
# - Consider a health clinic that screens women for a specific medical test the number of women comming in for screening varies daily. the clinic direotor needs to plan resources such as staff and equiment based on how many women are expected to come in each day.
# # Calculating the expected values:
# - To obtain the expected values of a discrete random variable can assume by the probability of occurrence of that values and then sum these produts
# - Thus expected values can be defind as the weighted average of outcomes.

# %% [markdown]
# # How do we describe a probability distribution?
# - A Probability distribution can be described in the following ways each offering a diffrent prespective :-
#
#   - Probability Density Function (PDF)
#   - Probability mass function (PMF)
#   - Culmulative Density Function (CDF)

# %% [markdown]
# # Probability Mass function  (PMF) :
# - Applies specifically to discrete random variable the PMF a probability distribution gives the Probability that discrete random variable is exactly equal to same value.
#   - Example : The Probability of rolling 5 on a dies
#     - P(x=5) = 1/6

# %% [markdown]
# # Probability Density Function (PDF):
# - Applies specifically to continuouns ramdom variable
# - The PDF of a probability distribution gives the probability of a continuons random variable to take or particular value.
# - More precisely the probability of taking on any single exact value is essentially zero. the PDF instead helps to calculate the proabability of the variable falling with in a certain interval.
#    - Example : - USing a PDF we can find the probability of the height of an individual to be between 150 cm and 150.2 cm here we are finding the probability for a range(150-150.2) and not for an individual value.

# %% [markdown]
# # Camulative Density Function (CDF):
# - Applies to both discrete and continuous random variables.
# - The Comulative Density Function (CDF) of a probability distribution tells you the probability that the random variable will be less than or equal to a certain value.
#   - Example : Measurring heights of individuals continuous random variable.
#   - Using a CDF we can find.
#   - P(height <_ 1.7 cm) the probability of same one being 1.7 meter or shorter
#   - P(height <_ 1.8 cm) the probability of same one being 1.8 meter or shorter.
#   - 2 imagine a simple case where you roll a fair six- sided die (Discrete random variable).
#    - The PMF would give the probability of rolling a 1,2,3,4,5 or 6 each of which is 1/6 the CDF all value 3 for instance would be the probability of rolling less.

# %% [markdown]
# # Normal Distribution (Guussion Distribution):
# - The normal distribution is a type of continuous probability distribution.
# - A bell-shaped probability distribution
# - Symmetrical bell cerve mean, Median , Mode coincide at the peak.
# # Standard Deviation (σ) :
# - Controls the width of the curve, higher mean wider spred.
# - A Normal Distribution is denoted by the symbol  N (μ, σ)

# %% [markdown]
# # Standard Normal Distribution :
# -The simplest of a normal distribution is know as the standard normal distribution or unit normal distribution this is a special case when μ = 0 σ = 1
# - Simplification of calculation with a mean of 0 and standard deviations 1 .
# # Normalization standardization and Regularisation :
# - Are critical techniques in machine learing each serving a distinct purpose in model development and performance optimization.
# # standardization :
# - Tranform data to have zero mean unit variance ensuring features contribute equally to model trunining the process inessential for models sensitive to feature scales like support vecto machine(svms) and K - neartest.
