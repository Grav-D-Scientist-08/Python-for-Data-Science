# %% [markdown]
# # Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data strutrues.

# %%
import seaborn as sns

# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001FD602EE750>

# %%
help(sns.load_dataset)
# Out:
# Help on function load_dataset in module seaborn.utils:
#
# load_dataset(name, cache=True, data_home=None, **kws)
#     Load an example dataset from the online repository (requires internet).
#
#     This function provides quick access to a small number of example datasets
#     that are useful for documenting seaborn or generating reproducible examples
#     for bug reports. It is not necessary for normal usage.
#
#     Note that some of the datasets have a small amount of preprocessing applied
#     to define a proper ordering for categorical variables.
#
#     Use :func:`get_dataset_names` to see a list of available datasets.
#
#     Parameters
#     ----------
#     name : str
#         Name of the dataset (``{name}.csv`` on
#         https://github.com/mwaskom/seaborn-data).
#     cache : boolean, optional
#         If True, try to load from the local cache first, and save to the cache
#         if a download is required.
#     data_home : string, optional
# ...

# %%
df = sns.load_dataset("tips")   # try using flights dataset
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()

# %%
# ba
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_theme(style = "whitegrid")

# %%
sns.barplot(data = df , x = "sex",y = "tip")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data = df , x = "time",y = "total_bill")
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(data = df ,x = "time",y ="total_bill",hue= "sex") # try giving hue = "sex"
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
#histogram
sns.histplot(data = df , x = "total_bill" )
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#histogram
sns.histplot(data = df , x = "total_bill" ,hue = "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Scatter plot
sns.scatterplot(data = df , x = "total_bill",y = "tip",hue ="smoker") # try giving , hue = "sex"
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Line Plot
sns.set_theme()
sns.lineplot(data = df , x = "total_bill",y = "tip" ,hue = "smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df1 = sns.load_dataset("flights")
df1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.countplot(data = df1 , x = "year")
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
sns.barplot(data = df1 , x = "year",y ="passengers" ,hue ="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data= df1, x = "year",y = "passengers",hue = "month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
import seaborn as sns

# %%
df2 = sns.load_dataset("exercise")
df2
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.countplot(data = df2, x = "diet")
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
sns.lineplot(data = df2 , x = "time",y = "pulse", hue = "kind")
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
sns.barplot(data = df2 ,x = "diet",y = "pulse")
# Out:
# <Axes: xlabel='diet', ylabel='pulse'>

# %%
for x in range(5):
    for y in range(x):
        print(" * ",end = "")
        #r = "*"
        #y*r
    print(x)
# Out:
# 0
#  * 1
#  *  * 2
#  *  *  * 3
#  *  *  *  * 4

# %%
n =5
for i in range(n):
    for j in range(n):
        print(" * ",end = "abc")
    print("")
# Out:
#  * abc * abc * abc * abc * abc
#  * abc * abc * abc * abc * abc
#  * abc * abc * abc * abc * abc
#  * abc * abc * abc * abc * abc
#  * abc * abc * abc * abc * abc
