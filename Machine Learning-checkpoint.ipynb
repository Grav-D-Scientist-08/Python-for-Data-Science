# %%
# !pip install wquantiles

# %%
# importin necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt     # visualization libaray
import seaborn as sns       # visualization libaray
from scipy.stats import trim_mean
import wquantiles    # uses to calculate the wighted quantiles
from statsmodels import robust     # for calculateing the mean absolute deviation

# %%
state = pd.read_csv("C:\\Users\\gaura\\OneDrive\\Desktop\\Machine learning\\state.csv")
state.head()
# Out:
#         State  Population  Murder.Rate Abbreviation
# 0     Alabama     4779736          5.7           AL
# 1      Alaska      710231          5.6           AK
# 2     Arizona     6392017          4.7           AZ
# 3    Arkansas     2915918          5.6           AR
# 4  California    37253956          4.4           CA

# %%
state
# Out:
#              State  Population  Murder.Rate Abbreviation
# 0          Alabama     4779736          5.7           AL
# 1           Alaska      710231          5.6           AK
# 2          Arizona     6392017          4.7           AZ
# 3         Arkansas     2915918          5.6           AR
# 4       California    37253956          4.4           CA
# 5         Colorado     5029196          2.8           CO
# 6      Connecticut     3574097          2.4           CT
# 7         Delaware      897934          5.8           DE
# 8          Florida    18801310          5.8           FL
# 9          Georgia     9687653          5.7           GA
# 10          Hawaii     1360301          1.8           HI
# 11           Idaho     1567582          2.0           ID
# 12        Illinois    12830632          5.3           IL
# 13         Indiana     6483802          5.0           IN
# 14            Iowa     3046355          1.9           IA
# ...

# %%
state.tail()
# Out:
#             State  Population  Murder.Rate Abbreviation
# 45       Virginia     8001024          4.1           VA
# 46     Washington     6724540          2.5           WA
# 47  West Virginia     1852994          4.0           WV
# 48      Wisconsin     5686986          2.9           WI
# 49        Wyoming      563626          2.7           WY

# %%
# Calcalating mean of the Population feature
state["Population"].mean()
# Out:
# 6162876.3

# %%
trim_mean(state["Population"],0.1)  # Trims 10% from both the ends
# Out:
# 4783697.125

# %%
trim_mean(state["Population"],0.2)  # Trims 20% from both the ends
# Out:
# 4413915.966666667

# %%
# Calulate the weighted mean for "Murder.Rate"
# The weights have been assigned according to the population of the state 
np.average(state['Murder.Rate'], weights = state["Population"])
# Out:
# 4.445833981123393

# %%
np.average(state['Population'], weights = state["Murder.Rate"])
# Out:
# 6738594.411214954

# %%
# Calculating the weighted median 
wquantiles.median(state["Murder.Rate"], weights = state ["Population"])
# Out:
# 4.4

# %%
# Calculating the standard deviation for the Population feature 
state["Population"].std()
# Out:
# 6848235.347401142

# %%
wquantiles.median(state["Population"], weights = state ["Murder.Rate"])
# Out:
# 4705739.504132231

# %%
help(pd.Series.std)
# Out:
# Help on function std in module pandas.core.generic:
#
# std(self, axis=None, skipna=True, level=None, ddof=1, numeric_only=None, **kwargs)
#     Return sample standard deviation over requested axis.
#
#     Normalized by N-1 by default. This can be changed using the ddof argument.
#
#     Parameters
#     ----------
#     axis : {index (0)}
#         For `Series` this parameter is unused and defaults to 0.
#     skipna : bool, default True
#         Exclude NA/null values. If an entire row/column is NA, the result
#         will be NA.
#     level : int or level name, default None
#         If the axis is a MultiIndex (hierarchical), count along a
#         particular level, collapsing into a scalar.
#
#         .. deprecated:: 1.3.0
#             The level keyword is deprecated. Use groupby instead.
#     ddof : int, default 1
#         Delta Degrees of Freedom. The divisor used in calculations is N - ddof,
#         where N represents the number of elements.
# ...

# %%
# Calulating IQR for the Population feature
state["Population"].quantile(0.75) - state["Population"].quantile(0.25)
# Out:
# 4847308.0

# %%
# Calculating Mean Absolute Deviation for the Popolation feature
robust.scale.mad(state["Population"])
# Out:
# 3849876.1459979336

# %%
# Polting a boxplot to check the distribution of the data using pandas 
ax = (state["Population"]/1000000).plot.box()
ax.set_ylabel("Population (millions)")
# Out:
# Text(0, 0.5, 'Population (millions)')

# %%
# we can do the same thing altrenatively using matplotlib
plt.boxplot(state["Population"]/1000000)
plt.xlabel("Population")
plt.ylabel("Population Millions")
# Out:
# Text(0, 0.5, 'Population Millions')

# %%
binnedPopulation = pd.cut(state["Population"],10)
binnedPopulation.value_counts()
# Out:
# (526935.67, 4232659.0]      24
# (4232659.0, 7901692.0]      14
# (7901692.0, 11570725.0]      6
# (11570725.0, 15239758.0]     2
# (15239758.0, 18908791.0]     1
# (18908791.0, 22577824.0]     1
# (22577824.0, 26246857.0]     1
# (33584923.0, 37253956.0]     1
# (26246857.0, 29915890.0]     0
# (29915890.0, 33584923.0]     0
# Name: Population, dtype: int64

# %%
ax = (state["Population"] / 1000000).plot.hist(figsize=(4,4))  # Right Sekewed 
ax.set_xlabel("Population(millions)")
# Out:
# Text(0.5, 0, 'Population(millions)')

# %%
ax = state["Murder.Rate"].plot.hist(density = True , xlim = [0,12] ,bins = range(1,12))
state["Murder.Rate"].plot.density(ax=ax)
ax.set_xlabel("Murder.Rate (per 100,000)")
# Out:
# Text(0.5, 0, 'Murder.Rate (per 100,000)')

# %%
# Importing the dfw_airline data
dfw = pd.read_csv("Data sets\\dfw_airline.csv")
dfw
# Out:
#     Carrier      ATC   Weather  Security    Inbound
# 0  64263.16  84856.5  11235.42    343.15  118427.82

# %%
ax = dfw.transpose().plot.bar(figsize=(4,4), legend=False)
ax.set_xlabel("Cause of delay")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Correlation:

# %%
sp500_sym = pd.read_csv("C:Data sets\\sp500_sectors.csv")
sp500_px = pd.read_csv("C:\\Users\\gaura\\OneDrive\\Desktop\\Machine learning\\sp500_data.csv.gz",index_col=0)

# %%
sp500_sym.head()
# Out:
#                    sector sector_label                             sub_sector  \
# 0  information_technology   Technology  data_processing_&_outsourced_services
# 1  information_technology   Technology                       systems_software
# 2  information_technology   Technology                       systems_software
# 3  information_technology   Technology                       systems_software
# 4  information_technology   Technology               it_consulting_&_services
#
#   symbol
# 0    ADS
# 1     CA
# 2   MSFT
# 3    RHT
# 4   CTSH

# %%
sp500_px.head()
# Out:
#             ADS        CA      MSFT  RHT  CTSH       CSC       EMC       IBM  \
# 1993-01-29  0.0  0.060124 -0.022100  0.0   0.0  0.018897  0.007368  0.092165
# 1993-02-01  0.0 -0.180389  0.027621  0.0   0.0  0.018889  0.018425  0.115207
# 1993-02-02  0.0 -0.120257  0.035900  0.0   0.0 -0.075573  0.029482 -0.023041
# 1993-02-03  0.0  0.060124 -0.024857  0.0   0.0 -0.151128  0.003689 -0.253454
# 1993-02-04  0.0 -0.360770 -0.060757  0.0   0.0  0.113350 -0.022114  0.069862
#
#                  XRX      ALTR  ...  WAT  ALXN     AMGN  BXLT     BIIB  \
# 1993-01-29  0.259140 -0.007105  ...  0.0   0.0  0.34716   0.0  0.04167
# 1993-02-01 -0.100775  0.063893  ...  0.0   0.0 -0.23144   0.0  0.00000
# 1993-02-02  0.028796 -0.014192  ...  0.0   0.0 -0.11572   0.0  0.00000
# 1993-02-03 -0.043190 -0.007105  ...  0.0   0.0 -0.08679   0.0  0.04167
# 1993-02-04  0.000000 -0.007096  ...  0.0   0.0  0.14465   0.0 -0.04166
#
#                CELG      GILD  REGN    VRTX  HSIC
# ...

# %%
sp500_sym.sector.unique()
# Out:
# array(['information_technology', 'industrials', 'energy',
#        'consumer_discretionary', 'utilities', 'materials', 'etf',
#        'telecommunications_services', 'consumer_staples', 'financials',
#        'health_care'], dtype=object)

# %%
etfs = sp500_px.loc[sp500_px.index > "2012-07-01" ,
                   sp500_sym[sp500_sym["sector"] == "etf"]["symbol"]]
sns.heatmap(etfs.corr(), vmin=-1 , vmax=1,
           cmap=sns.diverging_palette(20, 220, as_cmap = True))
# Out:
# <Axes: >

# %%
etfs.corr()
# Out:
#           XLI       QQQ       SPY       DIA       GLD       VXX       USO  \
# XLI  1.000000  0.785865  0.888865  0.869680  0.056554 -0.468196  0.236881
# QQQ  0.785865  1.000000  0.908995  0.834440  0.043553 -0.470555  0.199492
# SPY  0.888865  0.908995  1.000000  0.953726  0.078722 -0.547074  0.272069
# DIA  0.869680  0.834440  0.953726  1.000000  0.051523 -0.511327  0.256793
# GLD  0.056554  0.043553  0.078722  0.051523  1.000000 -0.107488  0.216563
# VXX -0.468196 -0.470555 -0.547074 -0.511327 -0.107488  1.000000 -0.195397
# USO  0.236881  0.199492  0.272069  0.256793  0.216563 -0.195397  1.000000
# IWM  0.782380  0.810158  0.833937  0.758012  0.070110 -0.448942  0.249799
# XLE  0.650054  0.560044  0.713300  0.658311  0.188625 -0.448474  0.525943
# XLY  0.798080  0.839701  0.887028  0.847043  0.017467 -0.474756  0.183275
# XLU  0.380809  0.346667  0.481928  0.463364  0.121611 -0.260395  0.113182
# XLB  0.784144  0.713463  0.826053  0.787415  0.184366 -0.470890  0.324166
# ...

# %%
telecomSymbols = sp500_sym[sp500_sym["sector"] == "telecommunications_services"]["symbol"]
telecom = sp500_px.loc[sp500_px.index >= "2012-07-01" , telecomSymbols]
telecom.corr()
# Out:
#              T       CTL       FTR        VZ      LVLT
# T     1.000000  0.474683  0.327767  0.677612  0.278626
# CTL   0.474683  1.000000  0.419757  0.416604  0.286665
# FTR   0.327767  0.419757  1.000000  0.287386  0.260068
# VZ    0.677612  0.416604  0.287386  1.000000  0.242199
# LVLT  0.278626  0.286665  0.260068  0.242199  1.000000

# %%
ax = telecom.plot.scatter(x = "T", y = "VZ" , figsize = (4,4), marker = "$\u25EF$")
ax.set_xlabel("ATT (T)")
ax.set_ylabel("Verizon (VZ)")
ax.axhline(0, color = "grey" , lw = 1)
ax.axvline(0, color = "grey" , lw = 1)

plt.tight_layout()
plt.show()

# %%
kc_tax = pd.read_csv("Data Sets//kc_tax.csv.gz")
kc_tax.head()
# Out:
#    TaxAssessedValue  SqFtTotLiving  ZipCode
# 0               NaN           1730  98117.0
# 1          206000.0           1870  98002.0
# 2          303000.0           1530  98166.0
# 3          361000.0           2000  98108.0
# 4          459000.0           3150  98108.0

# %%
kc_tax.shape
# Out:
# (498249, 3)

# %%
kc_tax0 = kc_tax.loc[(kc_tax.TaxAssessedValue  < 750000) &
                    (kc_tax.SqFtTotLiving  > 100) &
                    (kc_tax.SqFtTotLiving  < 3500), :]
kc_tax0.shape
# Out:
# (432693, 3)

# %%
kc_tax0.head()
# Out:
#    TaxAssessedValue  SqFtTotLiving  ZipCode
# 1          206000.0           1870  98002.0
# 2          303000.0           1530  98166.0
# 3          361000.0           2000  98108.0
# 4          459000.0           3150  98108.0
# 5          223000.0           1570  98032.0

# %%
ax = kc_tax0.plot.hexbin(x = "SqFtTotLiving" ,y = "TaxAssessedValue",
                        gridsize=30, sharex=False, figsize=(5,4))
ax.set_xlabel("Finished Square Feet")
ax.set_ylabel("Tax-Assessed Value")
# Out:
# Text(0, 0.5, 'Tax-Assessed Value')

# %%
plt.scatter(kc_tax0.SqFtTotLiving,kc_tax0.TaxAssessedValue,marker="+")
plt.xlabel("SqFtTotLiving")
plt.ylabel("TaxAssessedValue")
# Out:
# Text(0, 0.5, 'TaxAssessedValue')

# %%
fig, ax = plt.subplots(figsize=(4,4))
sns.kdeplot(data= kc_tax0.sample(10000), x = "SqFtTotLiving", y = "TaxAssessedValue", ax=ax ,fill=True)
ax.set_xlabel("Finished Squre Feet")
ax.set_ylabel("Tax Assessed Value")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Two Categorical Variables

# %%
lc_loans = pd.read_csv("Data Sets//lc_loans.csv")

# %%
lc_loans.head(20)
# Out:
#          status grade
# 0    Fully Paid     B
# 1   Charged Off     C
# 2    Fully Paid     C
# 3    Fully Paid     C
# 4       Current     B
# 5    Fully Paid     A
# 6       Current     C
# 7    Fully Paid     E
# 8   Charged Off     F
# 9   Charged Off     B
# 10   Fully Paid     C
# 11   Fully Paid     B
# 12  Charged Off     C
# 13   Fully Paid     B
# 14  Charged Off     B
# 15   Fully Paid     D
# 16   Fully Paid     C
# 17   Fully Paid     A
# 18   Fully Paid     B
# 19   Fully Paid     A

# %%
lc_loans.grade.unique()
# Out:
# array(['B', 'C', 'A', 'E', 'F', 'D', 'G'], dtype=object)

# %%
lc_loans.status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Late'], dtype=object)

# %%
crosstab = lc_loans.pivot_table(index="grade" ,columns = "status",
                                aggfunc=lambda x: len(x),margins=True)
crosstab
# Out:
# status  Charged Off  Current  Fully Paid  Late     All
# grade
# A              1562    50051       20408   469   72490
# B              5302    93852       31160  2056  132370
# C              6023    88928       23147  2777  120875
# D              5007    53281       13681  2308   74277
# E              2842    24639        5949  1374   34804
# F              1526     8444        2328   606   12904
# G               409     1990         643   199    3241
# All           22671   321185       97316  9789  450961

# %%
df = crosstab.loc["A":"G",:].copy()
df.loc[:,"Charged Off" : "Late"] = df.loc[:,"Charged Off": "Late"].div(df["All"],
                                                                       axis = 0)
df["All"] = df ["All"] / sum(df["All"])
perc_crosstab = df

# %%
perc_crosstab
# Out:
# status  Charged Off   Current  Fully Paid      Late       All
# grade
# A          0.021548  0.690454    0.281528  0.006470  0.160746
# B          0.040054  0.709013    0.235401  0.015532  0.293529
# C          0.049828  0.735702    0.191495  0.022974  0.268039
# D          0.067410  0.717328    0.184189  0.031073  0.164708
# E          0.081657  0.707936    0.170929  0.039478  0.077177
# F          0.118258  0.654371    0.180409  0.046962  0.028614
# G          0.126196  0.614008    0.198396  0.061401  0.007187

# %%
airline_stats = pd.read_csv("Data Sets//airline_stats.csv")
airline_stats.tail(50)
# Out:
#        pct_carrier_delay  pct_atc_delay  pct_weather_delay    airline
# 33418           4.746147       2.396192           0.121487  Southwest
# 33419           6.269044       3.050243           0.307942  Southwest
# 33420           4.592909       1.969796           0.066316  Southwest
# 33421           5.600590       2.477064           0.141874  Southwest
# 33422           7.802657       2.586338           0.210626  Southwest
# 33423           5.489224       1.818966           0.215517  Southwest
# 33424           6.420207       1.213548           0.216992  Southwest
# 33425           6.532995       1.416244           0.543147  Southwest
# 33426           8.556911       1.256098           0.406504  Southwest
# 33427           4.072089       2.315157           0.094270  Southwest
# 33428           5.541872       3.804187           0.555419  Southwest
# 33429           5.015355       3.439113           0.169972  Southwest
# ...

# %%
airline_stats.airline.unique()
# Out:
# array(['American', 'Alaska', 'Jet Blue', 'Delta', 'United', 'Southwest'],
#       dtype=object)

# %%
ax = airline_stats.boxplot(by = "airline", column = "pct_carrier_delay",
                           figsize = (5,5))
ax.set_xlabel("")
ax.set_ylabel("Daily % of Delayed Flights")
plt.suptitle("")

plt.tight_layout()
plt.show()

# %%
ax = sns.violinplot(x = airline_stats.airline, y=airline_stats.pct_carrier_delay,
                    inner='quartile', color= "yellow")
# ax = sns.violinplot(data = airline_stats , x = "airline" ,y = "pct_carrier_delay")
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')
# Out:
# Text(0, 0.5, 'Daily % of Delayed Flights')

# %%
zip_codes = [98188, 98105, 98108, 98126]
kc_tax_zip = kc_tax0.loc[kc_tax0.ZipCode.isin(zip_codes),:]
kc_tax_zip
def hexbin(x, y, color, **kwargs):
 cmap = sns.light_palette(color, as_cmap=True)
 plt.hexbin(x, y, gridsize=25, cmap=cmap, **kwargs)
g = sns.FacetGrid(kc_tax_zip, col='ZipCode', col_wrap=2)
g.map(hexbin, 'SqFtTotLiving', 'TaxAssessedValue',
 extent=[0, 3500, 0, 700000])
g.set_axis_labels('Finished Square Feet', 'Tax-Assessed Value')
g.set_titles('Zip code {col_name:.0f}')
